# %% [markdown]
# ### Learning Outcomes
#
# After this lab, students will be able to:
# - implement a RAG pipeline
# - analyze LLM outputs critically
# - evaluate system reliability

# %%
# %pip install -q google-genai sentence-transformers faiss-cpu
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.genai as genai
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# %%
API_KEY = "GEMINI_API_KEY"

client = genai.Client(api_key=API_KEY)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explique overfitting em português"
)

print(response.text)
# Out:
# **Overfitting (ou Sobreajuste)** é um problema comum e crucial em Machine Learning onde um modelo aprende os dados de treinamento "demais".
#
# Isso significa que, em vez de aprender padrões gerais e fundamentais que são úteis para fazer previsões precisas em novos dados, ele acaba memorizando o "ruído" e as particularidades específicas dos dados que usou para ser treinado.
#
# **Imagine a seguinte analogia:**
#
# Pense em um estudante que está se preparando para uma prova. Em vez de entender os conceitos e a lógica por trás da matéria, ele simplesmente decora as respostas de um conjunto específico de questões que o professor deu como exemplo.
#
# *   **O que acontece?** Quando ele faz a prova, se as perguntas forem **exatamente as mesmas** que ele decorou, ele terá um ótimo desempenho (100% de acerto!).
# *   **O problema:** Mas se as perguntas forem **ligeiramente diferentes**, mesmo que testem os mesmos conceitos, ele terá grandes dificuldades porque não compreendeu a lógica por trás. Ele só memorizou.
#
# Da mesma forma, um modelo com overfitting se sai muito bem com os dados de treinamento (que ele "memorizou"), mas tem um desempenho ruim com dados novos e não vistos (como as perguntas diferentes da prova).
#
# ---
#
# ### **Causas Comuns do Overfitting:**
#
# 1.  **Modelo muito complexo:** Quando o modelo tem capacidade excessiva para a quantidade e complexidade dos dados. Ele tem "liberdade" demais para encontrar padrões, mesmo os que não são reais.
# 2.  **Poucos dados de treinamento:** Se o conjunto de dados para treinar o modelo é pequeno, o modelo tem menos exemplos para aprender padrões verdadeiros e mais chances de memorizar os detalhes de cada um.
# 3.  **Treinamento excessivo:** Deixar o modelo treinando por muito tempo. Inicialmente, ele aprende os padrões úteis. Mas depois de um certo ponto, ele começa a aprender o ruído e as especificidades desnecessárias dos dados de treinamento.
# 4.  **Ruído nos dados:** Dados de treinamento com muitos erros ou inconsistências podem ser "memorizados" pelo modelo.
#
# ---
#
# ### **Consequências do Overfitting:**
#
# *   **Baixa performance em dados novos:** A principal consequência é que o modelo terá um desempenho significativamente pior quando encontrar dados do "mundo real" que não fazem parte do seu conjunto de treinamento.
# *   **Tomada de decisões erradas:** Em aplicações práticas (saúde, finanças, recomendação), isso pode levar a previsões imprecisas e decisões problemáticas.
# *   **Modelo não confiável:** O modelo não é robusto nem confiável para o propósito real para o qual foi construído.
#
# ---
#
# ### **Como Identificar o Overfitting:**
#
# A maneira mais comum de identificar overfitting é monitorar o desempenho do seu modelo em dois conjuntos de dados separados:
#
# 1.  **Conjunto de Treinamento (Training Set):** Dados usados para ensinar o modelo.
# 2.  **Conjunto de Validação/Teste (Validation/Test Set):** Dados "novos" que o modelo nunca viu durante o treinamento, usados para avaliar sua capacidade de generalização.
#
# **Sinal de Overfitting:** Se o modelo apresenta um desempenho **muito bom no conjunto de treinamento** (alta acurácia, baixo erro) mas um desempenho **significativamente pior no conjunto de validação/teste**, é um forte indicativo de overfitting.
#
# ---
#
# ### **Como Mitigar/Evitar o Overfitting:**
#
# 1.  **Mais dados de treinamento:** A melhor solução é sempre fornecer mais dados representativos ao modelo. Quanto mais exemplos ele tiver, menor a chance de ele memorizar particularidades.
# 2.  **Simplificar o modelo:** Reduzir o número de parâmetros, camadas ou características (features) que o modelo pode aprender.
# 3.  **Regularização:** Técnicas que adicionam uma penalidade à função de custo do modelo por ter pesos muito grandes ou complexos, incentivando-o a aprender padrões mais simples (ex: L1, L2, Dropout em redes neurais).
# 4.  **Early Stopping (Parada Antecipada):** Monitorar o desempenho no conjunto de validação durante o treinamento e parar o processo assim que o desempenho neste conjunto começar a piorar (mesmo que o desempenho no conjunto de treinamento ainda esteja melhorando).
# 5.  **Validação Cruzada (Cross-Validation):** Ajuda a garantir que o modelo seja avaliado de forma robusta em diferentes subconjuntos de dados, reduzindo o risco de overfitting a um único conjunto de validação.
# 6.  **Seleção de Features (Feature Selection):** Escolher apenas as características mais relevantes dos dados e descartar as que introduzem ruído ou são redundantes.
#
# ---
#
# Em resumo, overfitting é quando um modelo de Machine Learning "memoriza" o conjunto de dados de treinamento em vez de aprender os padrões subjacentes. Isso resulta em um excelente desempenho nos dados que ele já viu, mas um desempenho fraco e não confiável em dados novos e desconhecidos, comprometendo a utilidade do modelo no mundo real.

# %%
documents = [
    "A otimização da cadeia de suprimentos envolve a redução de custos, mantendo os níveis de serviço.",
    "A gestão de estoque é fundamental para equilibrar a oferta e a demanda.",
    "Os custos de transporte são uma componente importante das despesas logísticas.",
    "A previsão da demanda ajuda a reduzir a incerteza nas cadeias de abastecimento.",
    "As relações com os fornecedores influenciam a eficiência e a resiliência."
]

# %%
embedder = SentenceTransformer("all-MiniLM-L6-v2")
doc_embeddings = embedder.encode(documents)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
index = faiss.IndexFlatL2(doc_embeddings.shape[1])
index.add(np.array(doc_embeddings))

# %%
def retrieve(query, k=2):
    q_emb = embedder.encode([query])
    distances, indices = index.search(np.array(q_emb), k)
    return [documents[i] for i in indices[0]]

# %%
def ask_llm(prompt):
    return client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )

# %%
query = "Como reduzir os custos da cadeia de suprimentos?"

simple = ask_llm(query)

structured = ask_llm(f"Explique claramente: {query}")

context = retrieve(query)
rag_prompt = f"""
Use o seguinte contexto:
{context}

Resposta:
{query}
"""
rag = ask_llm(rag_prompt)

print("SIMPLES:\n", simple)
print("\nESTRUTURADA:\n", structured)
print("\nRAG:\n", rag)
# Out:
# SIMPLES:
#  sdk_http_response=HttpResponse(
#   headers=<dict len=12>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Reduzir os custos da cadeia de suprimentos é um objetivo fundamental para a maioria das empresas, pois impacta diretamente a lucratividade e a competitividade. É um processo contínuo que exige uma abordagem estratégica e multifacetada.
#
# Aqui estão as principais estratégias e táticas para reduzir os custos da cadeia de suprimentos:
#
# ### 1. Gestão de Estoque Otimizada
#
# *   **Previsão de Demanda Precisa:** Melhore a acuracidade das previsões de vendas para evitar excesso ou falta de estoque, utilizando dados históricos, tendências de mercado e ferramentas de análise avançada (IA/ML).
# *   **Inventário Just-in-Time (JIT):** Adote ou aprimore a metodologia JIT para receber materiais e produzir produtos apenas quando necessários, minimizando os custos de armazenagem e obsolescência.
# *   **Otimização do Estoque de Segurança:** Calcule e ajuste o estoque de segurança com base na variabilidade da demanda e do tempo de entrega, evitando capital parado desnecessário.
# *   **Racionalização de SKUs (Stock Keeping Units):** Avalie e elimine produtos de baixo giro ou não lucrativos para simplificar o estoque e reduzir custos de gestão.
# *   **Cross-Docking:** Utilize o cross-docking para movimentar produtos diretamente de caminhões de entrada para caminhões de saída, minimizando a necessidade de armazenamento prolongado.
#
# ### 2. Otimização do Transporte
#
# *   **Consolidação de Cargas:** Agrupe remessas menores em cargas maiores (Full Truckload - FTL) para reduzir custos por unidade, em vez de várias cargas parciais (Less than Truckload - LTL).
# *   **Otimização de Rotas e Planejamento de Entregas:** Utilize softwares de otimização de rotas para encontrar os caminhos mais eficientes, minimizar a distância percorrida, o tempo e o consumo de combustível.
# *   **Seleção de Modalidade de Transporte Adequada:** Escolha o modal de transporte (rodoviário, ferroviário, marítimo, aéreo) que oferece o melhor equilíbrio entre custo, velocidade e confiabilidade para cada tipo de produto e destino.
# *   **Negociação com Transportadoras:** Estabeleça parcerias estratégicas com transportadoras e negocie contratos de longo prazo com base em volume, desempenho e serviço.
# *   **Backhauling (Viagens de Retorno):** Procure oportunidades para as transportadoras levarem cargas no caminho de volta, aproveitando a capacidade ociosa e reduzindo custos.
# *   **Monitoramento e Otimização da Última Milha:** A etapa final da entrega (last-mile) é a mais cara. Invista em tecnologia e estratégias para otimizá-la, como pontos de coleta, roteirização inteligente e frotas mais eficientes.
#
# ### 3. Gestão de Fornecedores e Compras
#
# *   **Negociação Estratégica:** Negocie agressivamente os preços, prazos de pagamento e termos contratuais com os fornecedores, explorando volumes de compra e concorrência.
# *   **Consolidação de Fornecedores:** Reduza o número de fornecedores para obter maior poder de compra, simplificar a gestão e fortalecer relacionamentos.
# *   **Desenvolvimento de Fornecedores:** Colabore com fornecedores para encontrar maneiras de reduzir custos em conjunto, melhorar a qualidade e otimizar processos.
# *   **Auditoria de Custos de Fornecedores:** Analise a estrutura de custos dos fornecedores para identificar oportunidades de economia e garantir preços justos.
# *   **Global Sourcing vs. Local Sourcing:** Avalie o equilíbrio entre custos mais baixos de fornecedores globais e os benefícios de agilidade e menores custos de transporte de fornecedores locais.
#
# ### 4. Eficiência na Armazenagem e Operações
#
# *   **Otimização de Layout do Armazém:** Redesenhe o layout para melhorar o fluxo de materiais, reduzir o tempo de movimentação e otimizar o uso do espaço.
# *   **Automação:** Invista em tecnologias de automação como sistemas de gerenciamento de armazém (WMS), robôs, empilhadeiras automáticas e sistemas de picking para reduzir custos de mão de obra e aumentar a eficiência.
# *   **Gestão de Energia:** Implemente medidas de eficiência energética (iluminação LED, otimização de climatização) para reduzir os custos operacionais do armazém.
# *   **Minimização de Perdas e Danos:** Melhore processos de manuseio e embalagem para reduzir avarias, roubos e perdas de estoque.
# *   **Terceirização (3PLs/4PLs):** Considere terceirizar a logística (operadores logísticos 3PL ou 4PL) para aproveitar sua expertise, escala e tecnologia, convertendo custos fixos em variáveis.
#
# ### 5. Tecnologia e Análise de Dados
#
# *   **Sistemas de Gerenciamento (ERP, WMS, TMS, APS):** Implemente e integre sistemas que fornecem visibilidade, automação e controle sobre toda a cadeia de suprimentos.
# *   **Análise de Big Data:** Utilize ferramentas de análise de dados para identificar gargalos, ineficiências, padrões de custo e oportunidades de melhoria.
# *   **Inteligência Artificial e Machine Learning:** Aplique IA/ML para melhorar a previsão de demanda, otimizar estoques, roteirização e planejamento de capacidade.
# *   **IoT (Internet das Coisas):** Utilize sensores IoT para monitorar ativos, rastrear remessas em tempo real e obter dados para otimização.
#
# ### 6. Colaboração e Parcerias
#
# *   **Colaboração com Clientes:** Trabalhe em conjunto com os clientes para entender suas necessidades, otimizar entregas e reduzir devoluções.
# *   **Compartilhamento de Informações:** Promova o compartilhamento de dados e informações (previsões de demanda, níveis de estoque) com fornecedores e clientes para melhorar a coordenação e reduzir incertezas.
# *   **VMI (Vendor-Managed Inventory):** Permita que fornecedores gerenciem o estoque em suas instalações para otimizar os níveis de estoque e reduzir custos administrativos.
#
# ### 7. Gestão de Riscos e Sustentabilidade
#
# *   **Diversificação de Fornecedores e Rotas:** Reduza a dependência de um único fornecedor ou rota para mitigar riscos de interrupção que podem gerar custos extras.
# *   **Logística Reversa Eficiente:** Otimize os processos de devolução, reparo e reciclagem para recuperar valor de produtos e componentes.
# *   **Embalagens Sustentáveis e Otimizadas:** Reduza o desperdício de embalagem e otimize seu design para diminuir o peso e volume das remessas, impactando o custo de transporte.
# *   **Redução de Desperdício:** Identifique e elimine desperdícios em todos os processos da cadeia, desde a matéria-prima até o produto final.
#
# ### Considerações Finais:
#
# *   **Visão Holística:** A redução de custos na cadeia de suprimentos deve ser vista de forma holística. Uma economia em uma área pode gerar custos maiores em outra se não houver uma visão integrada.
# *   **Análise de Dados Contínua:** Acompanhe KPIs (Key Performance Indicators) relevantes para monitorar o desempenho e identificar novas oportunidades.
# *   **Cultura de Melhoria Contínua:** Fomente uma cultura organizacional que busca constantemente otimizar processos e reduzir custos.
# *   **Investimento em Pessoas:** Capacite sua equipe para que ela possa identificar e implementar melhorias.
#
# Comece identificando os pontos de maior gasto em sua cadeia de suprimentos e priorize as ações com maior potencial de retorno."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='4O_DadS8LLLmxN8PtvvZUA' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=1688,
#   prompt_token_count=11,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=11
#     ),
#   ],
#   thoughts_token_count=1289,
#   total_token_count=2988
# ) automatic_function_calling_history=[] parsed=None
#
# ESTRUTURADA:
#  sdk_http_response=HttpResponse(
#   headers=<dict len=12>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Reduzir os custos da cadeia de suprimentos é uma estratégia fundamental para aumentar a lucratividade, a competitividade e a resiliência de uma empresa. Envolve uma análise detalhada e a otimização de todas as etapas, desde a aquisição de matérias-primas até a entrega final ao cliente.
#
# Aqui está um guia claro e detalhado sobre como reduzir os custos da cadeia de suprimentos:
#
# ---
#
# ### Estratégias para Reduzir os Custos da Cadeia de Suprimentos
#
# Podemos agrupar as estratégias em categorias principais para facilitar a compreensão:
#
# **1. Otimização da Gestão de Fornecedores e Compras (Procurement)**
#
# *   **Negociação Estratégica:**
#     *   **Compras por Volume:** Consolidar pedidos para obter descontos por volume.
#     *   **Contratos de Longo Prazo:** Negociar preços fixos ou descontos progressivos para fornecimentos contínuos.
#     *   **Parcerias Estratégicas:** Desenvolver relacionamentos sólidos com fornecedores-chave para obter melhores condições, prioridade e colaboração em inovação.
# *   **Análise do Custo Total de Propriedade (TCO - Total Cost of Ownership):**
#     *   Não focar apenas no preço de compra, mas considerar todos os custos associados: frete, impostos, seguros, armazenamento, inspeção, custos de qualidade (defeitos), manutenção e descarte. Um fornecedor aparentemente mais caro pode ter um TCO menor.
# *   **Diversificação e Otimização da Base de Fornecedores:**
#     *   Ter múltiplos fornecedores para itens críticos para evitar dependência e ter poder de barganha, mas sem pulverizar demais, o que dificulta a gestão. Consolidar fornecedores para ter mais poder de compra.
# *   **Padronização de Componentes:**
#     *   Sempre que possível, padronizar componentes e matérias-primas. Isso reduz a complexidade, permite compras em maior volume e simplifica o gerenciamento de estoque.
#
# **2. Otimização da Gestão de Estoques**
#
# *   **Previsão de Demanda Aprimorada:**
#     *   Utilizar ferramentas de análise de dados e algoritmos preditivos (IA/ML) para prever a demanda com maior precisão. Uma previsão acurada reduz o excesso de estoque (custos de armazenagem e obsolescência) e a falta de estoque (perda de vendas e custos de pedidos urgentes).
# *   **Implementação de Just-in-Time (JIT) ou Lean Manufacturing:**
#     *   Receber materiais apenas quando são necessários para a produção, minimizando a necessidade de grandes estoques e reduzindo os custos de armazenagem e capital imobilizado.
# *   **Classificação ABC de Estoque:**
#     *   Categorizar itens de estoque com base em seu valor e volume de movimentação. Focar os esforços de gestão (contagem, segurança, reabastecimento) nos itens de maior valor (Classe A), que representam a maior parte do capital.
# *   **Otimização dos Níveis de Estoque de Segurança:**
#     *   Calcular os níveis de estoque de segurança de forma mais precisa, baseando-se na variabilidade da demanda e do lead time do fornecedor, em vez de usar estimativas arbitrárias.
# *   **Redução de Perdas e Obsolescência:**
#     *   Melhorar o controle de qualidade para reduzir devoluções e refugos. Implementar um sistema de rotação de estoque (FIFO - Primeiro que Entra, Primeiro que Sai) para produtos perecíveis ou com validade, prevenindo a obsolescência.
#
# **3. Otimização da Logística e Transporte**
#
# *   **Otimização de Rotas e Consolidação de Cargas:**
#     *   Utilizar softwares de roteirização para planejar as rotas mais eficientes. Consolidar cargas para encher os veículos (LTL para FTL - Less Than Truckload para Full Truckload), reduzindo o número de viagens e os custos por unidade transportada.
# *   **Escolha Inteligente de Modalidades de Transporte:**
#     *   Avaliar e escolher a modalidade de transporte mais econômica (rodoviário, ferroviário, marítimo, aéreo) com base na urgência, distância e volume. O transporte aéreo é rápido, mas caro; o marítimo é lento, mas muito mais barato para grandes volumes.
# *   **Otimização de Armazéns e Centros de Distribuição:**
#     *   Melhorar o layout do armazém para aumentar a eficiência na movimentação de produtos. Investir em automação (se o volume justificar) para reduzir custos de mão de obra e erros. Otimizar a localização dos CDs para reduzir as distâncias de entrega.
# *   **Logística Reversa Eficiente:**
#     *   Desenvolver processos eficientes para o retorno de produtos (defeitos, fim de vida útil, embalagens reutilizáveis), minimizando os custos de manuseio e transporte e maximizando o valor de recuperação (reparo, reciclagem).
# *   **Backhauling (Viagens de Retorno):**
#     *   Organizar cargas para as viagens de retorno dos veículos, evitando que voltem vazios e gerando receita ou reduzindo custos operacionais.
#
# **4. Otimização de Processos Internos**
#
# *   **Automação e Digitalização:**
#     *   Automatizar tarefas repetitivas e manuais em todas as etapas da cadeia de suprimentos (processamento de pedidos, inventário, faturamento) para reduzir erros e custos de mão de obra.
#     *   Digitalizar documentos e processos para reduzir o uso de papel e agilizar a comunicação.
# *   **Melhoria Contínua (Kaizen):**
#     *   Implementar uma cultura de melhoria contínua, encorajando os funcionários a identificar e propor soluções para ineficiências e desperdícios em seus processos diários.
# *   **Controle de Qualidade Robusto:**
#     *   Reduzir defeitos e retrabalho na produção, o que economiza materiais, tempo e recursos, além de evitar custos de devolução e perda de clientes.
# *   **Design para a Cadeia de Suprimentos (DfSC):**
#     *   Projetar produtos considerando a facilidade de fabricação, montagem, embalagem, transporte e reciclagem. Isso pode reduzir significativamente os custos em todas as etapas.
#
# **5. Tecnologia e Análise de Dados**
#
# *   **Sistemas de Gerenciamento (ERP, WMS, TMS, APS):**
#     *   Investir em sistemas de planejamento de recursos empresariais (ERP), gerenciamento de armazéns (WMS), gerenciamento de transporte (TMS) e planejamento avançado de produção (APS) para integrar informações, otimizar processos e ter visibilidade em tempo real.
# *   **Big Data e Análise Preditiva:**
#     *   Utilizar dados para identificar padrões, prever tendências (demanda, preços de commodities) e tomar decisões mais informadas sobre estoque, compras e logística.
# *   **Visibilidade da Cadeia de Suprimentos:**
#     *   Ter visibilidade de ponta a ponta sobre onde os produtos estão em cada momento, permite identificar gargalos, antecipar problemas e reagir rapidamente, evitando interrupções caras.
# *   **IoT (Internet das Coisas):**
#     *   Sensores em equipamentos, veículos e produtos podem fornecer dados em tempo real sobre localização, temperatura, umidade, etc., otimizando condições e evitando perdas.
#
# **6. Colaboração e Parcerias**
#
# *   **Integração com Fornecedores e Clientes:**
#     *   Compartilhar informações e planejar em conjunto com fornecedores e clientes para otimizar os fluxos de material e informação, reduzindo incertezas e custos.
#     *   Exemplo: VMI (Vendor-Managed Inventory), onde o fornecedor gerencia o estoque do cliente.
# *   **Parcerias com Operadores Logísticos (3PL/4PL):**
#     *   Terceirizar a logística para empresas especializadas (3PL - Third-Party Logistics ou 4PL - Fourth-Party Logistics) que podem oferecer economias de escala, expertise e tecnologia que a empresa não teria internamente.
#
# **7. Sustentabilidade na Cadeia de Suprimentos**
#
# *   **Redução de Resíduos:**
#     *   Programas de reciclagem, reutilização e redução de materiais de embalagem não só são bons para o meio ambiente, mas também reduzem custos de descarte e compra de materiais.
# *   **Eficiência Energética:**
#     *   Investir em equipamentos e instalações mais eficientes em energia (iluminação LED, veículos elétricos) para reduzir as contas de energia na produção e transporte.
# *   **Otimização de Embalagens:**
#     *   Redesenhar embalagens para serem mais leves, mais compactas e mais resistentes, o que reduz custos de material, espaço de armazenamento e frete, além de diminuir danos.
#
# ---
#
# ### Princípios Fundamentais para a Redução de Custos
#
# *   **Visibilidade de Ponta a Ponta:** Você não pode otimizar o que não vê. Tenha clareza sobre todos os custos e processos.
# *   **Abordagem Holística:** Não otimize apenas uma parte da cadeia de suprimentos isoladamente. Uma otimização em uma área pode impactar negativamente outra. Pense no sistema como um todo.
# *   **Análise de Dados Constante:** Use métricas e KPIs (Indicadores Chave de Performance) para monitorar custos, identificar tendências e medir o impacto das mudanças.
# *   **Cultura de Melhoria Contínua:** A redução de custos não é um projeto único, mas um processo contínuo que exige engajamento de todos os níveis da organização.
#
# Ao implementar uma combinação dessas estratégias de forma estratégica e contínua, as empresas podem alcançar reduções significativas nos custos da cadeia de suprimentos, melhorando sua performance geral e sustentabilidade."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='7-_Dad7mOrWAxs0Pia_qyAk' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=2193,
#   prompt_token_count=15,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=15
#     ),
#   ],
#   thoughts_token_count=1558,
#   total_token_count=3766
# ) automatic_function_calling_history=[] parsed=None
#
# RAG:
#  sdk_http_response=HttpResponse(
#   headers=<dict len=12>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text='Para reduzir os custos da cadeia de suprimentos, deve-se focar na **otimização da cadeia de suprimentos**. Além disso, a **previsão da demanda** ajuda a reduzir a incerteza nas cadeias de abastecimento, o que pode contribuir para a redução de custos.'
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='A_DDaY6IGqPWvdIP67il-A8' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=61,
#   prompt_token_count=66,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=66
#     ),
#   ],
#   thoughts_token_count=1068,
#   total_token_count=1195
# ) automatic_function_calling_history=[] parsed=None

# %%
print("""
Compare:

- Qual é mais factual?
- Qual usa melhor contexto?
- Qual é mais confiável?
""")
# Out:
# Compare:
#
# - Qual é mais factual?
# - Qual usa melhor contexto?
# - Qual é mais confiável?
