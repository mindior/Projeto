# %%
# Exemplo simples

import google.genai as genai

API_KEY = "GEMINI_API_KEY"

client = genai.Client(api_key=API_KEY)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explique como as IA podem melhorar a eficiência da cadeia de abastecimento."
)

print(response.text)

# %%
print("""
QUESTÕES:

- Por que o modelo deu essa resposta?
- Quais fatores influenciaram?
- Esta explicação é suficiente?
- Como validar?
""")
